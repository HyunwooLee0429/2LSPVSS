# %% [markdown]
# ## Various size Strip packing problem

# %% [markdown]
# This experiments aims to validate the computational tractabililty of the extended strip packing model.
#
# 1. Data Set Generation
# 2. Required parts calculation (different materials classification)
# 3. Opt_matching (Using Two dimensional Level Strip Packing Problem)
#    *Remainder consideration X
# 4. Matching group result recording
# 5. 20-days Keep going.

# %%
import pickle
import numpy as np
import pandas as pd

# %%
with open('LSP_single_results_rotation.pkl', 'rb') as f:
    LSP_single_results_rotation = pickle.load(f)

# %%
with open('LSP_double_results_1_rotation.pkl', 'rb') as f:
    LSP_double_results_1_rotation = pickle.load(f)

# %%
with open('LSP_double_results_2_rotation.pkl', 'rb') as f:
    LSP_double_results_2_rotation = pickle.load(f)

# %%
with open('LSP_triple_results_rotation.pkl', 'rb') as f:
    LSP_triple_results_rotation = pickle.load(f)

# %%
Datasets_rotation = {}
sizes = [60, 80, 100]
W = 100
W_set = [W, W, W, W, 10, 30, 40, 100, 100, 300]

with open('Datasets_rotation.pkl', 'rb') as f:
    Datasets_rotation = pickle.load(f)

# %%
matrix = np.zeros([len(Datasets_rotation)*len(sizes), 12])

# %%
for num in range(1,11):
    for i in range(len(sizes)):
        matrix[3*(num-1)+i][0] = LSP_single_results_rotation['class%s'%str(num)][sizes[i]]['total_area_avg'].getValue()
        matrix[3*(num-1)+i][1] = LSP_single_results_rotation['class%s'%str(num)][sizes[i]]['computation_time_avg']
        matrix[3*(num-1)+i][2] = LSP_single_results_rotation['class%s'%str(num)][sizes[i]]['optimality_gap_avg']
for num in range(1,11):
    for i in range(len(sizes)):
        matrix[3*(num-1)+i][3] = LSP_double_results_1_rotation['class%s'%str(num)][sizes[i]]['total_area_avg'].getValue()
        matrix[3*(num-1)+i][4] = LSP_double_results_1_rotation['class%s'%str(num)][sizes[i]]['computation_time_avg']
        matrix[3*(num-1)+i][5] = LSP_double_results_1_rotation['class%s'%str(num)][sizes[i]]['optimality_gap_avg']
for num in range(1,11):
    for i in range(len(sizes)):
        matrix[3*(num-1)+i][6] = LSP_double_results_2_rotation['class%s'%str(num)][sizes[i]]['total_area_avg'].getValue()
        matrix[3*(num-1)+i][7] = LSP_double_results_2_rotation['class%s'%str(num)][sizes[i]]['computation_time_avg']
        matrix[3*(num-1)+i][8] = LSP_double_results_2_rotation['class%s'%str(num)][sizes[i]]['optimality_gap_avg']
for num in range(1,11):
    for i in range(len(sizes)):
        matrix[3*(num-1)+i][9] = LSP_triple_results_rotation['class%s'%str(num)][sizes[i]]['total_area_avg'].getValue()
        matrix[3*(num-1)+i][10] = LSP_triple_results_rotation['class%s'%str(num)][sizes[i]]['computation_time_avg']
        matrix[3*(num-1)+i][11] = LSP_triple_results_rotation['class%s'%str(num)][sizes[i]]['optimality_gap_avg']

# %%
matrix
# Out:
# array([[1.39475176e+05, 2.36129270e+02, 1.77248821e-03, 1.39049997e+05,
#         3.00030039e+02, 4.64327243e-03, 1.38828321e+05, 3.00031488e+02,
#         4.24793090e-03, 1.38602643e+05, 3.00034522e+02, 4.20109271e-03],
#        [1.89638219e+05, 2.58476753e+02, 5.07800010e-03, 1.89230683e+05,
#         3.00037063e+02, 7.89755983e-03, 1.88910603e+05, 3.00039392e+02,
#         6.06874317e-03, 1.88644576e+05, 3.00066270e+02, 6.56379657e-03],
#        [2.43820616e+05, 3.00037709e+02, 4.41629207e-03, 2.43143281e+05,
#         3.00050214e+02, 7.42543352e-03, 2.43559699e+05, 3.00047430e+02,
#         9.41694257e-03, 2.42879530e+05, 3.00047338e+02, 7.77485976e-03],
#        [1.36619046e+05, 3.00020200e+02, 2.49268359e-03, 1.36205100e+05,
#         3.00028244e+02, 4.51912928e-03, 1.36255693e+05, 3.00023539e+02,
#         4.86738336e-03, 1.36063125e+05, 3.00031978e+02, 5.52120981e-03],
#        [1.88800300e+05, 3.00026073e+02, 4.05197791e-03, 1.88337517e+05,
# ...

# %%
index = [['class%d(%s)'%(num,size) for num in range(1,11) for size in sizes]]
columns = ['LSP_single_R_AREA','LSP_single_R_TIME','LSP_single_R_GAP',
           'LSP_double1_R_AREA','LSP_double1_R_TIME','LSP_double1_R_GAP',
           'LSP_double2_R_AREA','LSP_double2_R_TIME','LSP_double2_R_GAP',
           'LSP_triple_R_AREA','LSP_triple_R_TIME','LSP_triple_R_GAP']

# %%
df = pd.DataFrame(matrix, columns = columns, index = index)

# %%
df = df.round(3)
df
# Out:
#               LSP_single_R_AREA  LSP_single_R_TIME  LSP_single_R_GAP  \
# class1(60)           139475.176            236.129             0.002
# class1(80)           189638.219            258.477             0.005
# class1(100)          243820.616            300.038             0.004
# class2(60)           136619.046            300.020             0.002
# class2(80)           188800.300            300.026             0.004
# class2(100)          239872.624            300.036             0.006
# class3(60)           309905.933              0.093             0.000
# class3(80)           414266.159              0.105             0.000
# class3(100)          506474.091              0.190             0.000
# class4(60)            64884.018            295.820             0.002
# class4(80)            97610.345            300.032             0.003
# class4(100)          111285.466            300.051             0.006
# class5(60)             1865.315              1.332             0.000
# ...

# %%
df.describe()
# Out:
#        LSP_single_R_AREA  LSP_single_R_TIME  LSP_single_R_GAP  \
# count          30.000000          30.000000         30.000000
# mean       137800.793833         195.562167          0.007800
# std        132905.892821         134.633837          0.010077
# min          1808.409000           0.093000          0.000000
# 25%         21619.743250          23.538000          0.000000
# 50%        123952.256000         300.020500          0.002500
# 75%        214932.776750         300.031500          0.016250
# max        506474.091000         300.051000          0.027000
#
#        LSP_double1_R_AREA  LSP_double1_R_TIME  LSP_double1_R_GAP  \
# count           30.000000           30.000000          30.000000
# mean        133990.325000          235.844300           0.009133
# std         125257.020488          111.100672           0.010190
# min           1811.423000            0.915000           0.000000
# 25%          21720.179000          198.584250           0.001000
# ...

# %%
matrix = np.zeros([len(Datasets_rotation), 12])

# %%
for num in range(1,11):
    matrix[num-1][0] = 0
    matrix[num-1][1] = 0
    matrix[num-1][2] = 0
    for i in range(len(sizes)):
        matrix[num-1][0] += LSP_single_results_rotation['class%s'%str(num)][sizes[i]]['total_area_avg'].getValue()
        matrix[num-1][1] += LSP_single_results_rotation['class%s'%str(num)][sizes[i]]['computation_time_avg']
        matrix[num-1][2] += LSP_single_results_rotation['class%s'%str(num)][sizes[i]]['optimality_gap_avg']
for num in range(1,11):
    matrix[num-1][3] = 0
    matrix[num-1][4] = 0
    matrix[num-1][5] = 0
    for i in range(len(sizes)):
        matrix[num-1][3] += LSP_double_results_1_rotation['class%s'%str(num)][sizes[i]]['total_area_avg'].getValue()
        matrix[num-1][4] += LSP_double_results_1_rotation['class%s'%str(num)][sizes[i]]['computation_time_avg']
        matrix[num-1][5] += LSP_double_results_1_rotation['class%s'%str(num)][sizes[i]]['optimality_gap_avg']
for num in range(1,11):
    matrix[num-1][6] = 0
    matrix[num-1][7] = 0
    matrix[num-1][8] = 0
    for i in range(len(sizes)):
        matrix[num-1][6] += LSP_double_results_2_rotation['class%s'%str(num)][sizes[i]]['total_area_avg'].getValue()
        matrix[num-1][7] += LSP_double_results_2_rotation['class%s'%str(num)][sizes[i]]['computation_time_avg']
        matrix[num-1][8] += LSP_double_results_2_rotation['class%s'%str(num)][sizes[i]]['optimality_gap_avg']
for num in range(1,11):
    matrix[num-1][9] = 0
    matrix[num-1][10] = 0
    matrix[num-1][11] = 0
    for i in range(len(sizes)):
        matrix[num-1][9] += LSP_triple_results_rotation['class%s'%str(num)][sizes[i]]['total_area_avg'].getValue()
        matrix[num-1][10] += LSP_triple_results_rotation['class%s'%str(num)][sizes[i]]['computation_time_avg']
        matrix[num-1][11] += LSP_triple_results_rotation['class%s'%str(num)][sizes[i]]['optimality_gap_avg']

# %%
index = [['class%d'%(num) for num in range(1,11)]]
columns = ['LSP_single_R_AREA','LSP_single_R_TIME','LSP_single_R_GAP',
           'LSP_double1_R_AREA','LSP_double1_R_TIME','LSP_double1_R_GAP',
           'LSP_double2_R_AREA','LSP_double2_R_TIME','LSP_double2_R_GAP',
           'LSP_triple_R_AREA','LSP_triple_R_TIME','LSP_triple_R_GAP']

# %%
df1 = pd.DataFrame(matrix, columns = columns, index = index)

# %%
df1.loc['Total'] = df1.sum()

# %%
df1
# Out:
#             LSP_single_R_AREA  LSP_single_R_TIME  LSP_single_R_GAP  \
# (class1,)        5.729340e+05         794.643731          0.011267
# (class2,)        5.652920e+05         900.081969          0.012966
# (class3,)        1.230646e+06           0.388166          0.000155
# (class4,)        2.737798e+05         895.902620          0.011835
# (class5,)        7.730473e+03          15.769633          0.000093
# (class6,)        7.397808e+03         900.085597          0.071519
# (class7,)        7.971336e+04         422.984365          0.002114
# (class8,)        7.931519e+04         900.084013          0.055580
# (class9,)        6.390253e+05         136.830696          0.000370
# (class10,)       6.781897e+05         900.093923          0.070096
# Total            4.134024e+06        5866.864713          0.235994
#
#             LSP_double1_R_AREA  LSP_double1_R_TIME  LSP_double1_R_GAP  \
# (class1,)         5.714240e+05          900.117316           0.019966
# ...

# %%
for i in range(11):
    area = df1.iloc[i,0]
    time = df1.iloc[i,1]
    gap = df1.iloc[i,2]
    for j in range(4):
        df1.iloc[i,3*j] /= area
        df1.iloc[i,3*j+1] /= time
        df1.iloc[i,3*j+2] /= gap

# %%
df1.round(4)
# Out:
#             LSP_single_R_AREA  LSP_single_R_TIME  LSP_single_R_GAP  \
# (class1,)                 1.0                1.0               1.0
# (class2,)                 1.0                1.0               1.0
# (class3,)                 1.0                1.0               1.0
# (class4,)                 1.0                1.0               1.0
# (class5,)                 1.0                1.0               1.0
# (class6,)                 1.0                1.0               1.0
# (class7,)                 1.0                1.0               1.0
# (class8,)                 1.0                1.0               1.0
# (class9,)                 1.0                1.0               1.0
# (class10,)                1.0                1.0               1.0
# Total                     1.0                1.0               1.0
#
#             LSP_double1_R_AREA  LSP_double1_R_TIME  LSP_double1_R_GAP  \
# (class1,)               0.9974              1.1327             1.7721
# ...
